# %%
import torch

# %%
A = torch.arange(6, dtype=torch.float32).reshape(2, 3)

# %%
A
# Out:
# tensor([[0., 1., 2.],
#         [3., 4., 5.]])

# %%
sum_A = A.sum(axis=1, keepdim=True)
sum_A
# Out:
# tensor([[ 3.],
#         [12.]])

# %%
A / sum_A
# Out:
# tensor([[0.0000, 0.3333, 0.6667],
#         [0.2500, 0.3333, 0.4167]])

# %%
X = torch.rand(size=(2, 3, 4))
X.shape
# Out:
# torch.Size([2, 3, 4])

# %%
len(X[0])
# Out:
# 3

# %%
A
# Out:
# tensor([[0., 1., 2.],
#         [3., 4., 5.]])

# %%
A_sum = A.sum(axis=1)
A_sum
# Out:
# tensor([ 3., 12.])

# %%
A / A_sum
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 A / A_sum
#
# RuntimeError: The size of tensor a (3) must match the size of tensor b (2) at non-singleton dimension 1

# %%
X.shape
# Out:
# torch.Size([2, 3, 4])

# %%
X.sum(axis=0).shape
# Out:
# torch.Size([3, 4])

# %%
X.sum(axis=1).shape
# Out:
# torch.Size([2, 4])

# %%
A
# Out:
# tensor([[0., 1., 2.],
#         [3., 4., 5.]])

# %%
torch.linalg.norm(A)
# Out:
# tensor(7.4162)

# %%
X.shape
# Out:
# torch.Size([2, 3, 4])

# %%
torch.linalg.norm(X)
# Out:
# tensor(3.0380)

# %%
torch.linalg.norm(X.flatten())
# Out:
# tensor(3.0380)

# %%
A = torch.randn(10000, 10000)

# %%
B = torch.randn(10000, 8000)
C = torch.randn(8000, 10000)

# %%
A @ C.T
# Out:
# tensor([[  24.1695, -184.9315,   13.9925,  ...,   30.8900,  -15.8153,
#            81.4224],
#         [ -35.2005,   15.1325,  -64.5527,  ...,  198.8661,   46.0153,
#           -50.5955],
#         [ 106.4686,  -19.1219,  119.6214,  ...,  -36.9038,   -1.1462,
#           -74.2962],
#         ...,
#         [-188.8161,  -85.0900,   57.6463,  ...,  140.1173, -141.6408,
#            40.2230],
#         [ 110.9021,  -23.5648, -204.4281,  ...,  -92.4266,    9.1672,
#          -156.7163],
#         [-112.9633,   84.4827,   14.2142,  ...,  -86.8497, -213.6073,
#            89.5653]])

# %%
A = torch.rand(size=(100, 200))
B = torch.rand(size=(100, 200))
C = torch.rand(size=(100, 200))

# %%
tensor = torch.stack([A, B, C])
tensor.shape
# Out:
# torch.Size([3, 100, 200])
